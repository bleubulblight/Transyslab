# %%
import pandas as pd
import datetime
import os
import re
import openpyxl
from openpyxl import load_workbook
from openpyxl import Workbook

d_today = datetime.date.today()

# %%
# path_dir은 킨텍스-사업지구-존세분화 엑셀 파일만이 있는 경로로 지정합니다.
# 현재는 박현의 Local로 지정되어 있으므로, 각자 사용환경에 따라 경로 바꿔주시면 됩니다. 
path_dir = 'C:/GitRepo1/_LocalRepo(Bigfile)/[KINTEX]Cowork_220328_zonefile'

_filelink = list()

for file in os.listdir(path_dir) :
    _filelink.append(path_dir + '/' + file)
    

# 우리가 .csv 하위파일로 추출해야 하는 sheet의 A1 cell은, 아래 list에 있는 값들 중 하나의 값입니다. 이 값들의 집합을 val_list에 넣어줍니다.
# sheet의 A1이 아래 list 원소값중 하나일 경우, 이 sheet을 추출해서 .csv로 내보내겠다는 것을 의미합니다.(관련없는 csv도 내보내는 것 방지하기 위해 있는 list variable)
# 추가되는 교통수단이 있을 경우, val_list에 추가해주세요. 그래야 프로그램이 자동으로 해당 sheet를 추출합니다.
val_list = ['FD_pccar_taxi-od_O', 'FD_pccar_taxi-od_D', 'FD_bus-od_O', 'FD_bus-od_D', 'FD-F_fod_zone_O', 'FD-F_fod_zone_D']
testdic = dict()

for name in _filelink :
    load_wb = load_workbook(name, data_only=True)
    
    # 가끔 띄어쓰기 잘못해서 sheetname에 공백이 포함되어있는 경우 있음, 해당 공백을 제거한 결과로 sheet명을 자동변경.
    for sheetname in load_wb.sheetnames :
        new_ws = load_wb[sheetname]
        new_ws.title = new_ws.title.replace(" ", "")
        
    load_wb.save(name)
# Out:
# C:\Users\Hyun\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\drawings.py:59: UserWarning: wmf image format is not supported so the image is being dropped
#   warn(msg)

# %%
wb = Workbook()
for name in _filelink :
    load_wb = load_workbook(name, data_only=True)
    
    for sheetname in load_wb.sheetnames :
        
        if load_wb[sheetname]['A1'].value in val_list :
            savename = load_wb[sheetname].title
            ws = wb.active
            ws.title = load_wb[sheetname]['A1'].value
            ws['A1']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2025.xlsx]{}\'!A$1'.format(savename)
            ws['B1']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2025.xlsx]{}\'!B$1'.format(savename)
            ws['C1']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2025.xlsx]{}\'!C$1'.format(savename)
            
            ws['A2']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2025.xlsx]{}\'!A$2'.format(savename)
            ws['B2']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2025.xlsx]{}\'!B$2'.format(savename)
            ws['C2']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2025.xlsx]{}\'!C$2'.format(savename)
            
            ws['A3']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2030.xlsx]{}\'!A$2'.format(savename)
            ws['B3']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2030.xlsx]{}\'!B$2'.format(savename)
            ws['C3']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2030.xlsx]{}\'!C$2'.format(savename)
            
            ws['A4']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2035.xlsx]{}\'!A$2'.format(savename)
            ws['B4']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2035.xlsx]{}\'!B$2'.format(savename)
            ws['C4']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2035.xlsx]{}\'!C$2'.format(savename)
            
            ws['A5']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2040.xlsx]{}\'!A$2'.format(savename)
            ws['B5']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2040.xlsx]{}\'!B$2'.format(savename)
            ws['C5']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2040.xlsx]{}\'!C$2'.format(savename)
            
            ws['A6']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2045.xlsx]{}\'!A$2'.format(savename)
            ws['B6']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2045.xlsx]{}\'!B$2'.format(savename)
            ws['C6']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2045.xlsx]{}\'!C$2'.format(savename)
            
            ws['A7']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2050.xlsx]{}\'!A$2'.format(savename)
            ws['B7']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2050.xlsx]{}\'!B$2'.format(savename)
            ws['C7']= '=\'C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2050.xlsx]{}\'!C$2'.format(savename)
            
            savename = savename.replace(savename[-6:], d_today.strftime('%y%m%d'))
            wb.save("{}{}".format(savename, '.csv'))

# %%
mystring = 'exptD-FD-H_bus_od_zone_D_YYMMDD'

mystring = mystring.replace(mystring[-6:],'hello')

mystring

wb = Workbook()
for name in _filelink :
    load_wb = load_workbook(name, data_only=True)
    
    for sheetname in load_wb.sheetnames :
        
        if load_wb[sheetname]['A1'].value in val_list :
            savename = load_wb[sheetname].title
            ws = wb.active
            ws.title = load_wb[sheetname]['A1'].value
            ws['A1'] = ' \'=C:/GitRepo1/Transyslab/[킨텍스-사업지구-존세분화-220328-2025.xlsx]{}\'!A$1 '.format(savename)
            
            savename = savename.replace(savename[-6:], d_today.strftime('%y%m%d'))
            
            print(savename)
# Out:
# exptE-FD-H_pc_od_zone_O_220329
# exptE-FD-H_pc_od_zone_D_220329
# exptE-FD-H_bus_od_zone_O_220329
# exptE-FD-H_bus_od_zone_D_220329
# exptE-FD-F_fod_zone_O_220329
# exptE-FD-F_fod_zone_D_220329
# exptD-FD-H_pc_od_zone_O_220329
# exptD-FD-H_pc_od_zone_D_220329
# exptD-FD-H_bus_od_zone_O_220329
# exptD-FD-H_bus_od_zone_D_220329
# exptD-FD-F_fod_zone_O_220329
# exptD-FD-F_fod_zone_D_220329
# exptC-FD-H_pc_od_zone_O_220329
# exptC-FD-H_pc_od_zone_D_220329
# exptC-FD-H_bus_od_zone_O_220329
# exptC-FD-H_bus_od_zone_D_220329
# exptC-FD-F_fod_zone_O_220329
# exptC-FD-F_fod_zone_D_220329
# exptB-FD-H_pc_od_zone_O_220329
# exptB-FD-H_pc_od_zone_D_220329
# exptB-FD-H_bus_od_zone_O_220329
# exptB-FD-H_bus_od_zone_D_220329
# exptB-FD-F_fod_zone_O_220329
# exptB-FD-F_fod_zone_D_220329
# exptA-FD-H_pc_od_zone_O_220329
# exptA-FD-H_pc_od_zone_D_220329
# exptA-FD-H_bus_od_zone_O_220329
# exptA-FD-H_bus_od_zone_D_220329
# exptA-FD-F_fod_zone_O_220329
# exptA-FD-F_fod_zone_D_220329
# NON-FD-H_pc_od_zone_O_220329
# NON-FD-H_pc_od_zone_D_220329
# NON-FD-H_bus_od_zone_O_220329
# NON-FD-H_bus_od_zone_D_220329
# NON-FD-F_fod_zone_O_Y220329
# NON-FD-F_fod_zone_D_220329
# onlyA-FD-H_pc_od_zone_O_220329
# onlyA-FD-H_pc_od_zone_D_220329
# onlyA-FD-H_bus_od_zone_O_220329
# onlyA-FD-H_bus_od_zone_D_220329
# onlyA-FD-F_fod_zone_O_220329
# onlyA-FD-F_fod_zone_D_220329
# onlyB-FD-H_pc_od_zone_O_220329
# onlyB-FD-H_pc_od_zone_D_220329
# onlyB-FD-H_bus_od_zone_O_220329
# onlyB-FD-H_bus_od_zone_D_220329
# onlyA-FD-F_fod_zone_O_220329
# onlyA-FD-F_fod_zone_D_220329
# onlyB-FD-H_pc_od_zone_O_220329
# onlyB-FD-H_pc_od_zone_D_220329
# onlyB-FD-H_bus_od_zone_O_220329
# onlyB-FD-H_bus_od_zone_D_220329
# onlyB-FD-F_fod_zone_O_220329
# onlyB-FD-F_fod_zone_D_220329
# onlyC-FD-H_pc_od_zone_O_220329
# onlyC-FD-H_pc_od_zone_D_220329
# onlyC-FD-H_bus_od_zone_O_220329
# onlyC-FD-H_bus_od_zone_D_220329
# onlyC-FD-F_fod_zone_O_220329
# onlyC-FD-F_fod_zone_D_220329
# onlyD-FD-H_pc_od_zone_O_220329
# onlyD-FD-H_pc_od_zone_D_220329
# onlyD-FD-H_bus_od_zone_O_220329
# onlyD-FD-H_bus_od_zone_D_220329
# onlyD-FD-F_fod_zone_O_220329
# onlyD-FD-F_fod_zone_D_220329
# onlyE-FD-H_pc_od_zone_O_220329
# onlyE-FD-H_pc_od_zone_D_220329
# onlyE-FD-H_bus_od_zone_O_220329
# onlyE-FD-H_bus_od_zone_D_220329
# onlyE-FD-F_fod_zone_O_Y220329
# onlyE-FD-F_fod_zone_D_220329
# ALL-FD-H_pc_od_zone_O_220329
# ALL-FD-H_pc_od_zone_D_220329
# ALL-FD-H_bus_od_zone_O_220329
# ALL-FD-H_bus_od_zone_D_220329
# ALL-FD-F_fod_zone_O_220329
# ALL-FD-F_fod_zone_D_220329
# exptE-FD-H_pc_od_zone_O_220329
# exptE-FD-H_pc_od_zone_D_220329
# exptE-FD-H_bus_od_zone_O_220329
# exptE-FD-H_bus_od_zone_D_220329
# exptE-FD-F_fod_zone_O_220329
# exptE-FD-F_fod_zone_D_220329
# exptD-FD-H_pc_od_zone_O_220329
# exptD-FD-H_pc_od_zone_D_220329
# exptD-FD-H_bus_od_zone_O_220329
# exptD-FD-H_bus_od_zone_D_220329
# exptD-FD-F_fod_zone_O_220329
# exptD-FD-F_fod_zone_D_220329
# exptC-FD-H_pc_od_zone_O_220329
# exptC-FD-H_pc_od_zone_D_220329
# exptC-FD-H_bus_od_zone_O_220329
# exptC-FD-H_bus_od_zone_D_220329
# exptC-FD-F_fod_zone_O_220329
# exptC-FD-F_fod_zone_D_220329
# exptB-FD-H_pc_od_zone_O_220329
# exptB-FD-H_pc_od_zone_D_220329
# exptB-FD-H_bus_od_zone_O_220329
# exptB-FD-H_bus_od_zone_D_220329
# exptB-FD-F_fod_zone_O_220329
# exptB-FD-F_fod_zone_D_220329
# exptA-FD-H_pc_od_zone_O_220329
# exptA-FD-H_pc_od_zone_D_220329
# exptA-FD-H_bus_od_zone_O_220329
# exptA-FD-H_bus_od_zone_D_220329
# exptA-FD-F_fod_zone_O_220329
# exptA-FD-F_fod_zone_D_220329
# NON-FD-H_pc_od_zone_O_220329
# NON-FD-H_pc_od_zone_D_220329
# NON-FD-H_bus_od_zone_O_220329
# NON-FD-H_bus_od_zone_D_220329
# NON-FD-F_fod_zone_O_Y220329
# NON-FD-F_fod_zone_D_220329
# onlyA-FD-H_pc_od_zone_O_220329
# onlyA-FD-H_pc_od_zone_D_220329
# onlyA-FD-H_bus_od_zone_O_220329
# onlyA-FD-H_bus_od_zone_D_220329
# onlyA-FD-F_fod_zone_O_220329
# onlyA-FD-F_fod_zone_D_220329
# onlyB-FD-H_pc_od_zone_O_220329
# onlyB-FD-H_pc_od_zone_D_220329
# onlyB-FD-H_bus_od_zone_O_220329
# onlyB-FD-H_bus_od_zone_D_220329
# onlyB-FD-F_fod_zone_O_220329
# onlyB-FD-F_fod_zone_D_220329
# onlyC-FD-H_pc_od_zone_O_220329
# onlyC-FD-H_pc_od_zone_D_220329
# onlyC-FD-H_bus_od_zone_O_220329
# onlyC-FD-H_bus_od_zone_D_220329
# onlyC-FD-F_fod_zone_O_220329
# onlyC-FD-F_fod_zone_D_220329
# onlyD-FD-H_pc_od_zone_O_220329
# onlyD-FD-H_pc_od_zone_D_220329
# onlyD-FD-H_bus_od_zone_O_220329
# onlyD-FD-H_bus_od_zone_D_220329
# onlyD-FD-F_fod_zone_O_220329
# onlyD-FD-F_fod_zone_D_220329
# onlyE-FD-H_pc_od_zone_O_220329
# onlyE-FD-H_pc_od_zone_D_220329
# onlyE-FD-H_bus_od_zone_O_220329
# onlyE-FD-H_bus_od_zone_D_220329
# onlyE-FD-F_fod_zone_O_Y220329
# onlyE-FD-F_fod_zone_D_220329
# ALL-FD-H_pc_od_zone_O_220329
# ALL-FD-H_pc_od_zone_D_220329
# ALL-FD-H_bus_od_zone_O_220329
# ALL-FD-H_bus_od_zone_D_220329
# ALL-FD-F_fod_zone_O_220329
# ALL-FD-F_fod_zone_D_220329
# exptE-FD-H_pc_od_zone_O_220329
# exptE-FD-H_pc_od_zone_D_220329
# exptE-FD-H_bus_od_zone_O_220329
# exptE-FD-H_bus_od_zone_D_220329
# exptE-FD-F_fod_zone_O_220329
# exptE-FD-F_fod_zone_D_220329
# exptD-FD-H_pc_od_zone_O_220329
# exptD-FD-H_pc_od_zone_D_220329
# exptD-FD-H_bus_od_zone_O_220329
# exptD-FD-H_bus_od_zone_D_220329
# exptD-FD-F_fod_zone_O_220329
# exptD-FD-F_fod_zone_D_220329
# exptC-FD-H_pc_od_zone_O_220329
# exptC-FD-H_pc_od_zone_D_220329
# exptC-FD-H_bus_od_zone_O_220329
# exptC-FD-H_bus_od_zone_D_220329
# exptC-FD-F_fod_zone_O_220329
# exptC-FD-F_fod_zone_D_220329
# exptB-FD-H_pc_od_zone_O_220329
# exptB-FD-H_pc_od_zone_D_220329
# exptB-FD-H_bus_od_zone_O_220329
# exptB-FD-H_bus_od_zone_D_220329
# exptB-FD-F_fod_zone_O_220329
# exptB-FD-F_fod_zone_D_220329
# exptA-FD-H_pc_od_zone_O_220329
# exptA-FD-H_pc_od_zone_D_220329
# exptA-FD-H_bus_od_zone_O_220329
# exptA-FD-H_bus_od_zone_D_220329
# exptA-FD-F_fod_zone_O_220329
# exptA-FD-F_fod_zone_D_220329
# NON-FD-H_pc_od_zone_O_220329
# NON-FD-H_pc_od_zone_D_220329
# NON-FD-H_bus_od_zone_O_220329
# NON-FD-H_bus_od_zone_D_220329
# NON-FD-F_fod_zone_O_Y220329
# NON-FD-F_fod_zone_D_220329
# onlyA-FD-H_pc_od_zone_O_220329
# onlyA-FD-H_pc_od_zone_D_220329
# onlyA-FD-H_bus_od_zone_O_220329
# onlyA-FD-H_bus_od_zone_D_220329
# onlyA-FD-F_fod_zone_O_220329
# onlyA-FD-F_fod_zone_D_220329
# onlyB-FD-H_pc_od_zone_O_220329
# onlyB-FD-H_pc_od_zone_D_220329
# onlyB-FD-H_bus_od_zone_O_220329
# onlyB-FD-H_bus_od_zone_D_220329
# onlyB-FD-F_fod_zone_O_220329
# onlyB-FD-F_fod_zone_D_220329
# onlyC-FD-H_pc_od_zone_O_220329
# onlyC-FD-H_pc_od_zone_D_220329
# onlyC-FD-H_bus_od_zone_O_220329
# onlyC-FD-H_bus_od_zone_D_220329
# onlyC-FD-F_fod_zone_O_220329
# onlyC-FD-F_fod_zone_D_220329
# onlyD-FD-H_pc_od_zone_O_220329
# onlyD-FD-H_pc_od_zone_D_220329
# onlyD-FD-H_bus_od_zone_O_220329
# onlyD-FD-H_bus_od_zone_D_220329
# onlyD-FD-F_fod_zone_O_220329
# onlyD-FD-F_fod_zone_D_220329
# onlyE-FD-H_pc_od_zone_O_220329
# onlyE-FD-H_pc_od_zone_D_220329
# onlyE-FD-H_bus_od_zone_O_220329
# onlyE-FD-H_bus_od_zone_D_220329
# onlyE-FD-F_fod_zone_O_Y220329
# onlyE-FD-F_fod_zone_D_220329
# ALL-FD-H_pc_od_zone_O_220329
# ALL-FD-H_pc_od_zone_D_220329
# ALL-FD-H_bus_od_zone_O_220329
# ALL-FD-H_bus_od_zone_D_220329
# ALL-FD-F_fod_zone_O_220329
# ALL-FD-F_fod_zone_D_220329
# exptE-FD-H_pc_od_zone_O_220329
# exptE-FD-H_pc_od_zone_D_220329
# exptE-FD-H_bus_od_zone_O_220329
# exptE-FD-H_bus_od_zone_D_220329
# exptE-FD-F_fod_zone_O_220329
# exptE-FD-F_fod_zone_D_220329
# exptD-FD-H_pc_od_zone_O_220329
# exptD-FD-H_pc_od_zone_D_220329
# exptD-FD-H_bus_od_zone_O_220329
# exptD-FD-H_bus_od_zone_D_220329
# exptD-FD-F_fod_zone_O_220329
# exptD-FD-F_fod_zone_D_220329
# exptC-FD-H_pc_od_zone_O_220329
# exptC-FD-H_pc_od_zone_D_220329
# exptC-FD-H_bus_od_zone_O_220329
# exptC-FD-H_bus_od_zone_D_220329
# exptC-FD-F_fod_zone_O_220329
# exptC-FD-F_fod_zone_D_220329
# exptB-FD-H_pc_od_zone_O_220329
# exptB-FD-H_pc_od_zone_D_220329
# exptB-FD-H_bus_od_zone_O_220329
# exptB-FD-H_bus_od_zone_D_220329
# exptB-FD-F_fod_zone_O_220329
# exptB-FD-F_fod_zone_D_220329
# exptA-FD-H_pc_od_zone_O_220329
# exptA-FD-H_pc_od_zone_D_220329
# exptA-FD-H_bus_od_zone_O_220329
# exptA-FD-H_bus_od_zone_D_220329
# exptA-FD-F_fod_zone_O_220329
# exptA-FD-F_fod_zone_D_220329
# NON-FD-H_pc_od_zone_O_220329
# NON-FD-H_pc_od_zone_D_220329
# NON-FD-H_bus_od_zone_O_220329
# NON-FD-H_bus_od_zone_D_220329
# NON-FD-F_fod_zone_O_Y220329
# NON-FD-F_fod_zone_D_220329
# onlyA-FD-H_pc_od_zone_O_220329
# onlyA-FD-H_pc_od_zone_D_220329
# onlyA-FD-H_bus_od_zone_O_220329
# onlyA-FD-H_bus_od_zone_D_220329
# onlyA-FD-F_fod_zone_O_220329
# onlyA-FD-F_fod_zone_D_220329
# onlyB-FD-H_pc_od_zone_O_220329
# onlyB-FD-H_pc_od_zone_D_220329
# onlyB-FD-H_bus_od_zone_O_220329
# onlyB-FD-H_bus_od_zone_D_220329
# onlyB-FD-F_fod_zone_O_220329
# onlyB-FD-F_fod_zone_D_220329
# onlyC-FD-H_pc_od_zone_O_220329
# onlyC-FD-H_pc_od_zone_D_220329
# onlyC-FD-H_bus_od_zone_O_220329
# onlyC-FD-H_bus_od_zone_D_220329
# onlyC-FD-F_fod_zone_O_220329
# onlyC-FD-F_fod_zone_D_220329
# onlyD-FD-H_pc_od_zone_O_220329
# onlyD-FD-H_pc_od_zone_D_220329
# onlyD-FD-H_bus_od_zone_O_220329
# onlyD-FD-H_bus_od_zone_D_220329
# onlyD-FD-F_fod_zone_O_220329
# onlyD-FD-F_fod_zone_D_220329
# onlyE-FD-H_pc_od_zone_O_220329
# onlyE-FD-H_pc_od_zone_D_220329
# onlyE-FD-H_bus_od_zone_O_220329
# onlyE-FD-H_bus_od_zone_D_220329
# onlyE-FD-F_fod_zone_O_Y220329
# onlyE-FD-F_fod_zone_D_220329
# ALL-FD-H_pc_od_zone_O_220329
# ALL-FD-H_pc_od_zone_D_220329
# ALL-FD-H_bus_od_zone_O_220329
# ALL-FD-H_bus_od_zone_D_220329
# ALL-FD-F_fod_zone_O_220329
# ALL-FD-F_fod_zone_D_220329

# %%
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\GitRepo1\Transyslab\OutCsv.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/GitRepo1/Transyslab/OutCsv.ipynb#ch0000004?line=0'>1</a> pd.read_csv('C:\GitRepo1\Transyslab\ALL-FD-F_fod_zone_D_220329.csv', encoding='ISO-8859-1')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=579'>580</a> with parser:
# --> <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=580'>581</a>     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1250, in TextFileReader.read(self, nrows)
#    <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1247'>1248</a> nrows = validate_integer("nrows", nrows)
#    <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1248'>1249</a> try:
# -> <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1249'>1250</a>     index, columns, col_dict = self._engine.read(nrows)
#    <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1250'>1251</a> except Exception:
#    <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/readers.py?line=1251'>1252</a>     self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=222'>223</a> try:
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=223'>224</a>     if self.low_memory:
# --> <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=224'>225</a>         chunks = self._reader.read_low_memory(nrows)
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=225'>226</a>         # destructive to chunks
#     <a href='file:///c%3A/Users/Hyun/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=226'>227</a>         data = _concatenate_chunks(chunks)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 9, saw 4
